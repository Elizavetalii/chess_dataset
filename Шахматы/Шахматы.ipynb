# %% [markdown]
# Цель работы: научиться работать с датасетами.А так же реализовать базовый анализ датасета. Вывести весь датасет и описать его.Вывести размерноть массива.Вывести наименование всех колонок, написать что они означают.
# Вывести все уникальные значения. Отсортировать по определенным параметрам. Удалить ненужные столбцы или строчки. Заменить определенные значения в датасете.Удалить дубликаты.Провести анализ с помощью функций info.
# Провести анализ с помощью функций describe.Провести выборку данных по строкам и столбцам с помощью loc. Сохранить новый датасет.

# %%
import pandas as pd
import numpy as np

games = pd.read_csv("games.csv")
games
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %% [markdown]
# Пункт 1.Вывод датасета и его описание.
# Это набор состоит из чуть более 20 000 шахматных партий, собранных от избранных пользователей на сайте Lichess.org.
# Для каждой из этих отдельных игр от Lichess. Эти данные  собраны с помощью Lichess API, который позволяет собирать историю игр любого пользователя. На Lichess есть несколько команд с более чем 1500 игроками,  это эффективный способ привлечь пользователей к коллекционированию игр.

# %%
games.shape
# Out:
# (20058, 16)

# %% [markdown]
# Пункт 2.Размерноть массива количество строк 20058 и столбцов 16.

# %%
games.columns
# Out:
# Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')

# %% [markdown]
# Пункт 3.Вывод наименования всех колонок, написать их значения.
# Этот набор содержит:
# Идентификатор игры;
# Номинальный (Т/Ф);
# Время начала;
# Время окончания;
# Количество ходов;
# Статус игры;
# Победитель;
# Приращение времени;
# Белый идентификатор игрока;
# Рейтинг белого игрока;
# Черный идентификатор игрока;
# Рейтинг черных игроков;
# Все ходы в стандартной шахматной записи;
# Открытие Eco (стандартный код для любого открытия, перечислите здесь);
# Начальное имя;
# Открытие Ply (количество ходов в начальной фазе)

# %%
games["id"].unique()
# Out:
# array(['TZJHLljE', 'l1NXvwaE', 'mIICvQHh', ..., 'yrAas0Kj', 'b0v4tRyF',
#        'N8G2JHGG'], dtype=object)

# %%
games["rated"].unique()
# Out:
# array([False,  True])

# %%
games["created_at"].unique()
# Out:
# array([1.50421000e+12, 1.50413000e+12, 1.50411000e+12, ...,
#        1.49969788e+12, 1.49969613e+12, 1.49964315e+12])

# %%
games["last_move_at"].unique()
# Out:
# array([1.50421000e+12, 1.50413000e+12, 1.50411000e+12, ...,
#        1.49969805e+12, 1.49969707e+12, 1.49964389e+12])

# %%
games["turns"].unique()
# Out:
# array([ 13,  16,  61,  95,   5,  33,   9,  66, 119,  39,  38,  60,  31,
#         43,  52, 101,  25,  14,   3,  17,  36,  69,  54,  53,  64,  21,
#         11,  19,  28,  22,  37,  34,  32,  71,  30,  41,  49,   7,  35,
#          8,  44,  29,  40,  57,  78,  62,  87,  50, 131,  48,  47,  51,
#         58, 114,  20,  85, 113,  75, 135,  81,  46,  70,  91, 137,  18,
#        111,  90,  59,  26,  23, 118, 120,  24,   2,  97,  12,  72, 156,
#         77,  65,  73, 125,  76,  63, 107, 100,  80, 105, 144, 158, 117,
#        110, 178, 136, 124,  96,  10, 106,  15,  42, 159,  74, 112, 104,
#        150,  88,  55, 103, 177,  82,  99,  67,   6, 115,  83,  89, 116,
#         27, 102,  45,  98, 108,  92,  56, 123, 129,   4, 163, 130, 121,
#         94,  79, 148, 195, 122, 128,  84,  86,  93, 161, 133,  68, 153,
#        154, 160, 141, 132, 204, 140, 168, 127, 109, 174, 157, 142, 143,
#        170,   1, 138, 171, 145, 151, 179, 149, 173, 208, 139, 134, 169,
# ...

# %%
games["victory_status"].unique()
# Out:
# array(['outoftime', 'resign', 'mate', 'draw'], dtype=object)

# %%
games["winner"].unique()
# Out:
# array(['white', 'black', 'draw'], dtype=object)

# %%
games["increment_code"].unique()
# Out:
# array(['15+2', '5+10', '20+0', '30+3', '10+0', '15+30', '15+0', '20+60',
#        '5+40', '8+0', '15+15', '15+16', '11+0', '30+60', '15+5', '10+10',
#        '15+3', '18+0', '30+30', '20+25', '5+5', '30+0', '40+40', '16+0',
#        '6+10', '8+10', '8+12', '7+12', '15+10', '20+5', '20+10', '45+0',
#        '5+8', '30+2', '25+0', '10+2', '7+2', '25+25', '7+8', '6+6',
#        '10+4', '12+0', '15+1', '2+10', '9+0', '10+9', '6+7', '30+10',
#        '30+15', '10+3', '45+30', '9+2', '7+3', '6+5', '25+5', '5+7',
#        '8+2', '20+8', '30+5', '25+15', '15+7', '8+8', '5+9', '16+7',
#        '10+7', '7+5', '40+20', '10+5', '11+5', '10+15', '180+0', '17+5',
#        '8+5', '3+8', '60+120', '90+120', '15+8', '9+1', '9+3', '2+15',
#        '10+1', '5+12', '60+10', '5+60', '8+15', '30+25', '12+1', '14+0',
#        '60+20', '10+8', '20+3', '14+12', '7+7', '60+0', '45+45', '4+15',
#        '5+6', '180+180', '8+3', '4+6', '10+25', '3+10', '7+4', '6+3',
# ...

# %%
games["white_id"].unique()
# Out:
# array(['bourgris', 'a-00', 'ischia', ..., 'samael88', 'belcolt',
#        'marcodisogno'], dtype=object)

# %%
games["white_rating"].unique()
# Out:
# array([1500, 1322, 1496, ...,  860,  929,  880], dtype=int64)

# %%
games["black_id"].unique()
# Out:
# array(['a-00', 'skinnerua', 'adivanov2009', ..., 'farrukhasomiddinov',
#        'schaaksmurf3', 'ffbob'], dtype=object)

# %%
games["black_rating"].unique()
# Out:
# array([1191, 1261, 1500, ...,  840,  857,  860], dtype=int64)

# %%
games["moves"].unique()
# Out:
# array(['d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5 Bf4',
#        'd4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6 Qe5+ Nxe5 c4 Bb4+',
#        'e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc6 bxc6 Ra6 Nc4 a4 c3 a3 Nxa3 Rxa3 Rxa3 c4 dxc4 d5 cxd5 Qxd5 exd5 Be6 Ra8+ Ke7 Bc5+ Kf6 Bxf8 Kg6 Bxg7 Kxg7 dxe6 Kh6 exf7 Nf6 Rxh8 Nh5 Bxh5 Kg5 Rxh7 Kf5 Qf3+ Ke6 Bg4+ Kd6 Rh6+ Kc5 Qe3+ Kb5 c4+ Kb4 Qc3+ Ka4 Bd1#',
#        ...,
#        'd4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd2 b6 Ne5 Nxe5 Bxe5 Nd7 Bxh7+ Kxh7 Qh5+ Kg8 Nf3 f6 Bf4 g5 Qg6+ Kh8 Nh4 Qe8 Qh6+ Kg8 Ng6 Kf7 Qh7#',
# ...

# %%
games["opening_eco"].unique()
# Out:
# array(['D10', 'B00', 'C20', 'D02', 'C41', 'B27', 'D00', 'C50', 'B01',
#        'A00', 'C02', 'C00', 'C57', 'C55', 'A40', 'B20', 'A25', 'B21',
#        'D01', 'C45', 'D06', 'B52', 'D20', 'B06', 'A45', 'B77', 'A21',
#        'B70', 'B23', 'B76', 'C21', 'A80', 'A20', 'A04', 'C26', 'C44',
#        'E10', 'A41', 'C01', 'A10', 'C18', 'A47', 'C10', 'D80', 'D30',
#        'D41', 'A46', 'D31', 'C64', 'C24', 'A43', 'A08', 'B03', 'B29',
#        'B02', 'B13', 'B57', 'E20', 'E11', 'C40', 'C11', 'C28', 'B30',
#        'A56', 'C65', 'B90', 'B50', 'B51', 'E00', 'C70', 'B11', 'B22',
#        'B40', 'B31', 'B18', 'C61', 'C78', 'B10', 'C22', 'C54', 'C68',
#        'B12', 'C77', 'A42', 'C42', 'D07', 'B32', 'A22', 'C46', 'B07',
#        'A06', 'C60', 'A07', 'A02', 'C58', 'A03', 'B54', 'D03', 'C69',
#        'A31', 'D46', 'C34', 'C48', 'C47', 'B24', 'C67', 'E61', 'C53',
#        'C23', 'B96', 'A05', 'D92', 'A49', 'C37', 'A09', 'A01', 'C88',
# ...

# %%
games["opening_name"].unique()
# Out:
# array(['Slav Defense: Exchange Variation',
#        'Nimzowitsch Defense: Kennedy Variation',
#        "King's Pawn Game: Leonardis Variation", ...,
#        "Queen's Indian Defense: Classical Variation |  Traditional Variation",
#        "Queen's Gambit Declined: Slav |  Dutch Variation",
#        'Sicilian Defense: Najdorf Variation |  Polugaevsky Variation'],
#       dtype=object)

# %%
games["opening_ply"].unique()
# Out:
# array([ 5,  4,  3, 10,  6,  1,  9,  2,  8,  7, 17, 11, 12, 13, 18, 19, 15,
#        16, 14, 28, 20, 22, 24], dtype=int64)

# %% [markdown]
# Пункт 4.Вывести все уникальные значения. Вывод производтся по каждому столбцу отдельно.

# %%
games.sort_values(by='turns')
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 4828   Z1M9z44Z   True  1.472750e+12  1.472750e+12      1         resign
# 1946   3K5kYPO8   True  1.491530e+12  1.491530e+12      1         resign
# 4115   3NQKJmJ5  False  1.500760e+12  1.500760e+12      1      outoftime
# 13557  01dkNQ2O  False  1.504442e+12  1.504442e+12      1      outoftime
# 13560  LAFV9u5Q  False  1.504442e+12  1.504442e+12      1      outoftime
# ...         ...    ...           ...           ...    ...            ...
# 16645  5ZjOnwjl   True  1.480271e+12  1.480272e+12    226           draw
# 4236   vQq60Hur   True  1.474480e+12  1.474490e+12    255           draw
# 16386  cZiGllu7   True  1.481753e+12  1.481755e+12    259           draw
# 11554  pN0ioHNr   True  1.503084e+12  1.503086e+12    349      outoftime
# 13859  pN0ioHNr   True  1.503084e+12  1.503086e+12    349      outoftime
#
#       winner increment_code      white_id  white_rating       black_id  \
# ...

# %% [markdown]
# Пункт 5.Сортировка в таблице по количеству ходов в партии в порядке возрастания.

# %%
games.sort_values(by='black_rating',ascending=False)
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 4473   rAO6oybn  False  1.480830e+12  1.480830e+12      1      outoftime
# 12080  tgePSMBk  False  1.500474e+12  1.500476e+12     58         resign
# 12680  0C3HN9UQ  False  1.496967e+12  1.496967e+12     22         resign
# 12614  uH1mpzvB  False  1.500726e+12  1.500726e+12     17         resign
# 12615  2qndM9O7  False  1.500415e+12  1.500417e+12    104         resign
# ...         ...    ...           ...           ...    ...            ...
# 2891   Ls7pzvc7   True  1.486680e+12  1.486680e+12     60           mate
# 2328   FJZ23eFz  False  1.501010e+12  1.501010e+12     77           mate
# 15380  FJZ23eFz  False  1.501013e+12  1.501014e+12     77           mate
# 930    WRNkn1iH   True  1.498720e+12  1.498720e+12     74         resign
# 11465  516BT5yk   True  1.501445e+12  1.501446e+12    120         resign
#
#       winner increment_code          white_id  white_rating          black_id  \
# ...

# %% [markdown]
# Сортировка по рейтингу черных игроков в порядке убывания.

# %%
games.drop([1,2], axis=0, inplace=True)
games.drop([3,4], axis=0, inplace=True)
games
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 5      MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw
# 6      qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign
# 7      RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign
# 8      dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code            white_id  white_rating  \
# ...

# %% [markdown]
# Пункт 6.Удаление ненужных столбцов или строчек.Удаляем ненужные строчки из таблицы под номерами 1,2,3,4.

# %%
games = games.replace({"turns":13}, 18) 
games
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     18      outoftime
# 5      MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw
# 6      qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign
# 7      RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign
# 8      dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code            white_id  white_rating  \
# ...

# %% [markdown]
# Пункт 7.Заменить определенные значения в датасете (например, пустые). В столбце "turns" занчение 13 заменяется на 18.

# %%
games.drop_duplicates()
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 5      MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw
# 6      qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign
# 7      RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign
# 8      dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code            white_id  white_rating  \
# ...

# %% [markdown]
# Пункт 8.Удалеие дубликатов из датасета.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20054 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20054 non-null  object
#  1   rated           20054 non-null  bool
#  2   created_at      20054 non-null  float64
#  3   last_move_at    20054 non-null  float64
#  4   turns           20054 non-null  int64
#  5   victory_status  20054 non-null  object
#  6   winner          20054 non-null  object
#  7   increment_code  20054 non-null  object
#  8   white_id        20054 non-null  object
#  9   white_rating    20054 non-null  int64
#  10  black_id        20054 non-null  object
#  11  black_rating    20054 non-null  int64
#  12  moves           20054 non-null  object
#  13  opening_eco     20054 non-null  object
#  14  opening_name    20054 non-null  object
#  15  opening_ply     20054 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# ...

# %% [markdown]
# Пункт 9.Провести анализ с помощью функций info.В данном датасете существует 4 значения типа int, 2 float, 1 bool, 4 object. При выводе описано 16 колонок и 200057 строк.

# %%
games.describe()
# Out:
#          created_at  last_move_at         turns  white_rating  black_rating  \
# count  2.005400e+04  2.005400e+04  20054.000000  20054.000000  20054.000000
# mean   1.483613e+12  1.483614e+12     60.466441   1596.662112   1588.865463
# std    2.850288e+10  2.850277e+10     33.571578    291.272507    291.052479
# min    1.376772e+12  1.376772e+12      1.000000    784.000000    789.000000
# 25%    1.477536e+12  1.477540e+12     37.000000   1398.000000   1391.000000
# 50%    1.496001e+12  1.496002e+12     55.000000   1567.000000   1562.000000
# 75%    1.503170e+12  1.503170e+12     79.000000   1793.000000   1784.000000
# max    1.504493e+12  1.504494e+12    349.000000   2700.000000   2723.000000
#
#         opening_ply
# count  20054.000000
# mean       4.817194
# std        2.797366
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       28.000000

# %% [markdown]
# Пункт 10.Провести анализ с помощью функций describe.Который вывел для каждого столбца свои статические показатели,к примеру, видно, что максимальное значение в столбце  turns = 349.000000, а минимальное 1.000000.

# %%
subset = games.loc[[10,11,12,13], ['id','rated','turns']]
subset
# Out:
#           id  rated  turns
# 10  HgKLWPsz  False     39
# 11  Vf5fKWzI  False     38
# 12  HRti5mKv  False     60
# 13  2fEjSei6  False     31

# %% [markdown]
# Пункт 11.Провести выборку данных по строкам и столбцам с помощью loc. Были выбраны столбцы под названиями id	rated	turns , и строки 10,11,12,13.

# %%
games.to_csv("chess_clear.csv")

# %% [markdown]
# Пункт 12.Сохранить новый датасет под названием chess.

# %% [markdown]
# Вывод:  в ходе работы были полкчены навыки работы с датасетами.А так же реализован базовый анализ датасета. Выведен весь датасет и описан.Выведена размерноть массива.Выведено наименование всех колонок, описано, что они означают.Выведены все уникальные значения. Отсортированы по определенным параметрам. Удалины ненужные столбцы или строчки. Заменены определенные значения в датасете.Удалены дубликаты.Проведен анализ с помощью функций info.Проведен анализ с помощью функций describe.Проведена выборка данных по строкам и столбцам с помощью loc.
